# %% [markdown]
# #### (C) 2018 - Dimitri Wirjowerdojo
# ###### https://github.com/dmtr13/cluster/
#
# Processes MCL clustering results and create a heat-map of the Jaccard indices.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import glob, os

# %%
file95 = glob.glob("../Data/yesNull/*95.0*KEGG*")
sorted(file95)
# Out:
# ['../Data/yesNull/HPA_processed_Euclidean_95.0_MCL_KEGG.tsv',
#  '../Data/yesNull/HPA_processed_Manhattan_95.0_MCL_KEGG.tsv',
#  '../Data/yesNull/HPA_processed_Mass-Distance_95.0_MCL_KEGG.tsv',
#  '../Data/yesNull/HPA_processed_Relative-Euclidean_95.0_MCL_KEGG.tsv']

# %%
df = pd.read_csv(file95[0], sep='\t', index_col=0, header=0)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df, cmap='YlGnBu')
plt.show()
